# %%
# import the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# import the datasets
data = pd.read_csv("customer_shopping_behavior.csv")

# %%
data.head(10)
# Out:
#    Customer ID  Age Gender Item Purchased     Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse     Clothing                     53
# 1            2   19   Male        Sweater     Clothing                     64
# 2            3   50   Male          Jeans     Clothing                     73
# 3            4   21   Male        Sandals     Footwear                     90
# 4            5   45   Male         Blouse     Clothing                     49
# 5            6   46   Male       Sneakers     Footwear                     20
# 6            7   63   Male          Shirt     Clothing                     85
# 7            8   27   Male         Shorts     Clothing                     34
# 8            9   26   Male           Coat    Outerwear                     97
# 9           10   57   Male        Handbag  Accessories                     31
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
# 5        Wyoming    M      White  Summer            2.9                 Yes
# 6        Montana    M       Gray    Fall            3.2                 Yes
# 7      Louisiana    L   Charcoal  Winter            3.2                 Yes
# 8  West Virginia    L     Silver  Summer            2.6                 Yes
# 9       Missouri    M       Pink  Spring            4.8                 Yes
#
#     Shipping Type Discount Applied Promo Code Used  Previous Purchases  \
# 0         Express              Yes             Yes                  14
# 1         Express              Yes             Yes                   2
# 2   Free Shipping              Yes             Yes                  23
# 3    Next Day Air              Yes             Yes                  49
# 4   Free Shipping              Yes             Yes                  31
# 5        Standard              Yes             Yes                  14
# 6   Free Shipping              Yes             Yes                  49
# 7   Free Shipping              Yes             Yes                  19
# 8         Express              Yes             Yes                   8
# 9  2-Day Shipping              Yes             Yes                   4
#
#   Payment Method Frequency of Purchases
# 0          Venmo            Fortnightly
# 1           Cash            Fortnightly
# 2    Credit Card                 Weekly
# 3         PayPal                 Weekly
# 4         PayPal               Annually
# 5          Venmo                 Weekly
# 6           Cash              Quarterly
# 7    Credit Card                 Weekly
# 8          Venmo               Annually
# 9           Cash              Quarterly

# %%
data.info()

# %%
data.isnull().sum()
# Out:
# Customer ID                0
# Age                        0
# Gender                     0
# Item Purchased             0
# Category                   0
# Purchase Amount (USD)      0
# Location                   0
# Size                       0
# Color                      0
# Season                     0
# Review Rating             37
# Subscription Status        0
# Shipping Type              0
# Discount Applied           0
# Promo Code Used            0
# Previous Purchases         0
# Payment Method             0
# Frequency of Purchases     0
# dtype: int64

# %%
# Fill the na values using grouped median value
data['Review Rating'] = data.groupby('Category')['Review Rating'] \
    .transform(lambda x: x.fillna(x.median()))

# %%
data.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
# Cleanup the column and make it readbale and consistent
data.columns = data.columns.str.lower()
data.columns = data.columns.str.replace(' ', '_')

# %%
# make adjustment to this ambigious column name
data = data.rename(columns={'purchase_amount_(usd)': 'purchase_amount'})

# %%
data.info()

# %%
# Create a column of age groups for the customers
labels = ['Young Adult', 'Adult', 'Middle Aged', 'Senior']
data['age_group'] = pd.qcut(data['age'], q=4, labels=labels)

# %%
data.head(10)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             3900 non-null   int64
#  1   age                     3900 non-null   int64
#  2   gender                  3900 non-null   object
#  3   item_purchased          3900 non-null   object
#  4   category                3900 non-null   object
#  5   purchase_amount         3900 non-null   int64
#  6   location                3900 non-null   object
#  7   size                    3900 non-null   object
#  8   color                   3900 non-null   object
#  9   season                  3900 non-null   object
#  10  review_rating           3900 non-null   float64
#  11  subscription_status     3900 non-null   object
#  12  shipping_type           3900 non-null   object
#  13  discount_applied        3900 non-null   object
#  14  promo_code_used         3900 non-null   object
#  15  previous_purchases      3900 non-null   int64
#  16  payment_method          3900 non-null   object
#  17  frequency_of_purchases  3900 non-null   object
#  18  age_group               3900 non-null   category
# dtypes: category(1), float64(1), int64(4), object(13)
# memory usage: 552.6+ KB

# %%
# Create a column for purchase_frequency_days
frequency_mapping = {
    'Fortnightly' : 14,
    'Weekly' : 7,
    'Monthly' : 30,
    'Quarterly' : 90,  
    'Annually' : 365,
    'Bi-Weekly' : 14,
    'Every 3 Months' : 90
}

data['purchase_frequency_days'] = data['frequency_of_purchases'].map(frequency_mapping)

# %%
data.sample(5)
# Out:
#       customer_id  age  gender item_purchased  category  purchase_amount  \
# 2394         2395   40    Male        Sandals  Footwear               47
# 1533         1534   50    Male          Shoes  Footwear               59
# 795           796   39    Male        Sandals  Footwear               26
# 2917         2918   58  Female          Shirt  Clothing               45
# 2582         2583   19    Male          Dress  Clothing               98
#
#            location size   color  season  review_rating subscription_status  \
# 2394    Connecticut    L   Peach    Fall            2.9                  No
# 1533  New Hampshire    M    Gold  Summer            3.6                  No
# 795        New York    M   Beige  Summer            4.6                 Yes
# 2917       Colorado   XL   White  Winter            2.9                  No
# 2582   South Dakota    S  Indigo    Fall            3.6                  No
#
#        shipping_type discount_applied promo_code_used  previous_purchases  \
# 2394  2-Day Shipping               No              No                  23
# 1533  2-Day Shipping              Yes             Yes                  16
# 795     Store Pickup              Yes             Yes                  34
# 2917    Store Pickup               No              No                  50
# 2582  2-Day Shipping               No              No                   4
#
#      payment_method frequency_of_purchases    age_group  \
# 2394     Debit Card            Fortnightly        Adult
# 1533  Bank Transfer              Quarterly  Middle Aged
# 795           Venmo               Annually        Adult
# 2917          Venmo               Annually       Senior
# 2582          Venmo         Every 3 Months  Young Adult
#
#       purchase_frequency_days
# 2394                       14
# 1533                       90
# 795                       365
# 2917                      365
# 2582                       90

# %%
# Customer shopping behavior
data[['discount_applied', 'promo_code_used']].head(10)
# Out:
#   discount_applied promo_code_used
# 0              Yes             Yes
# 1              Yes             Yes
# 2              Yes             Yes
# 3              Yes             Yes
# 4              Yes             Yes
# 5              Yes             Yes
# 6              Yes             Yes
# 7              Yes             Yes
# 8              Yes             Yes
# 9              Yes             Yes

# %%
# See the column shares the corrosponding equal values

(data['discount_applied'] == data['promo_code_used']).all()
# Out:
# np.True_

# %%
# Drop the promo_code_used column
data = data.drop('promo_code_used', axis=1)

# %%
data.sample(10)
# Out:
#       customer_id  age  gender item_purchased     category  purchase_amount  \
# 1990         1991   32    Male       Backpack  Accessories               95
# 381           382   66    Male        Jewelry  Accessories               25
# 3220         3221   38  Female        Handbag  Accessories               29
# 2202         2203   42    Male          Dress     Clothing               36
# 1021         1022   55    Male           Coat    Outerwear               51
# 1463         1464   54    Male        Jewelry  Accessories               49
# 2320         2321   28    Male          Shoes     Footwear               55
# 2125         2126   57    Male           Coat    Outerwear               87
# 3497         3498   35  Female        Handbag  Accessories               48
# 3084         3085   46  Female          Scarf  Accessories               37
#
#            location size     color  season  review_rating subscription_status  \
# 1990    Connecticut    L     White  Spring            3.4                  No
# 381           Maine    L  Lavender  Winter            3.4                 Yes
# 3220   North Dakota    M      Blue    Fall            4.1                  No
# 2202        Alabama    M       Red  Summer            4.3                  No
# 1021  Massachusetts    S  Lavender  Winter            4.9                 Yes
# 1463       Oklahoma    M     Beige  Summer            4.9                  No
# 2320     New Mexico    M     Olive  Spring            3.7                  No
# 2125  New Hampshire    M     Beige    Fall            4.8                  No
# 3497       Colorado    M       Red  Spring            4.3                  No
# 3084          Idaho    S    Indigo  Spring            3.2                  No
#
#        shipping_type discount_applied  previous_purchases payment_method  \
# 1990  2-Day Shipping               No                  15         PayPal
# 381     Store Pickup              Yes                   3    Credit Card
# 3220   Free Shipping               No                  16           Cash
# 2202    Next Day Air               No                  23    Credit Card
# 1021  2-Day Shipping              Yes                  39         PayPal
# 1463    Store Pickup              Yes                   1  Bank Transfer
# 2320   Free Shipping               No                   9     Debit Card
# 2125    Store Pickup               No                  31         PayPal
# 3497    Store Pickup               No                  16          Venmo
# 3084    Store Pickup               No                  43         PayPal
#
#      frequency_of_purchases    age_group  purchase_frequency_days
# 1990               Annually        Adult                      365
# 381          Every 3 Months       Senior                       90
# 3220                Monthly        Adult                       30
# 2202                 Weekly        Adult                        7
# 1021                 Weekly  Middle Aged                        7
# 1463                Monthly  Middle Aged                       30
# 2320         Every 3 Months  Young Adult                       90
# 2125              Quarterly  Middle Aged                       90
# 3497         Every 3 Months        Adult                       90
# 3084                Monthly  Middle Aged                       30

# %%
# import psycopg2 binary and sqlalchemy
import psycopg2
import sqlalchemy
from sqlalchemy import create_engine

# %%
create_engine = create_engine('postgresql://postgres:1234ABSK@localhost:5432/customer_behavior')

# %%
# put the data into customer_behavior database
table_name = 'customer'
data.to_sql(name=table_name, con=create_engine, if_exists='append', index=False)
# Out:
# 900

# %%
pd.read_sql("SELECT * FROM customer", con=create_engine)
# Out:
#       customer_id  age  gender item_purchased     category  purchase_amount  \
# 0               1   55    Male         Blouse     Clothing               53
# 1               2   19    Male        Sweater     Clothing               64
# 2               3   50    Male          Jeans     Clothing               73
# 3               4   21    Male        Sandals     Footwear               90
# 4               5   45    Male         Blouse     Clothing               49
# ...           ...  ...     ...            ...          ...              ...
# 3895         3896   40  Female         Hoodie     Clothing               28
# 3896         3897   52  Female       Backpack  Accessories               49
# 3897         3898   46  Female           Belt  Accessories               33
# 3898         3899   44  Female          Shoes     Footwear               77
# 3899         3900   52  Female        Handbag  Accessories               81
#
#            location size      color  season  review_rating  \
# 0          Kentucky    L       Gray  Winter            3.1
# 1             Maine    L     Maroon  Winter            3.1
# 2     Massachusetts    S     Maroon  Spring            3.1
# 3      Rhode Island    M     Maroon  Spring            3.5
# 4            Oregon    M  Turquoise  Spring            2.7
# ...             ...  ...        ...     ...            ...
# 3895       Virginia    L  Turquoise  Summer            4.2
# 3896           Iowa    L      White  Spring            4.5
# 3897     New Jersey    L      Green  Spring            2.9
# 3898      Minnesota    S      Brown  Summer            3.8
# 3899     California    M      Beige  Spring            3.1
#
#      subscription_status   shipping_type discount_applied  previous_purchases  \
# 0                    Yes         Express              Yes                  14
# 1                    Yes         Express              Yes                   2
# 2                    Yes   Free Shipping              Yes                  23
# 3                    Yes    Next Day Air              Yes                  49
# 4                    Yes   Free Shipping              Yes                  31
# ...                  ...             ...              ...                 ...
# 3895                  No  2-Day Shipping               No                  32
# 3896                  No    Store Pickup               No                  41
# 3897                  No        Standard               No                  24
# 3898                  No         Express               No                  24
# 3899                  No    Store Pickup               No                  33
#
#      payment_method frequency_of_purchases    age_group  \
# 0             Venmo            Fortnightly  Middle Aged
# 1              Cash            Fortnightly  Young Adult
# 2       Credit Card                 Weekly  Middle Aged
# 3            PayPal                 Weekly  Young Adult
# 4            PayPal               Annually  Middle Aged
# ...             ...                    ...          ...
# 3895          Venmo                 Weekly        Adult
# 3896  Bank Transfer              Bi-Weekly  Middle Aged
# 3897          Venmo              Quarterly  Middle Aged
# 3898          Venmo                 Weekly        Adult
# 3899          Venmo              Quarterly  Middle Aged
#
#       purchase_frequency_days
# 0                          14
# 1                          14
# 2                           7
# 3                           7
# 4                         365
# ...                       ...
# 3895                        7
# 3896                       14
# 3897                       90
# 3898                        7
# 3899                       90
#
# [3900 rows x 19 columns]

# %%
len(data)
# Out:
# 3900
